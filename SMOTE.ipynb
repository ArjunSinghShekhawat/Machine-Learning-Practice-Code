# %%
#SMOTE

# %%
from sklearn.datasets import make_classification

# %%
x,y = make_classification(n_samples=1000,n_features=2,n_redundant=0,n_clusters_per_class=1,weights=[0.90],random_state=23)

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(x,columns=['f1','f2'])
df2 = pd.DataFrame(y,columns=['target'])
df = pd.concat([df1,df2],axis = 1)

# %%
df
# Out:
#            f1        f2  target
# 0   -0.592870  1.224422       0
# 1   -1.241040  0.643944       0
# 2   -1.120830 -0.393508       1
# 3   -2.169750 -0.130374       0
# 4   -2.020505  1.506183       1
# ..        ...       ...     ...
# 995 -1.351490  0.411348       0
# 996 -1.100950  1.001011       0
# 997 -0.777330 -1.372457       1
# 998 -1.394281  0.945315       0
# 999 -0.486401  2.295881       0
#
# [1000 rows x 3 columns]

# %%
df['target'].value_counts()
# Out:
# 0    899
# 1    101
# Name: target, dtype: int64

# %%
import seaborn as sns

# %%
sns.scatterplot(x = df['f1'],y = df['f2'],c= df['target'])
# Out:
# <AxesSubplot: xlabel='f1', ylabel='f2'>

# %%
# !pip install imblearn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.6/235.6 kB 7.9 MB/s eta 0:00:00
# ...

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample = SMOTE()

# %%
x,y =oversample.fit_resample(df[['f1','f2']],df['target'])

# %%
x.shape
# Out:
# (1798, 2)

# %%
y.shape
# Out:
# (1798,)

# %%
df1 = pd.DataFrame(x,columns=['f1','f2'])
df2 = pd.DataFrame(y,columns=['target'])
oversample = pd.concat([df1,df2],axis = 1)

# %%
oversample
# Out:
#             f1        f2  target
# 0    -0.592870  1.224422       0
# 1    -1.241040  0.643944       0
# 2    -1.120830 -0.393508       1
# 3    -2.169750 -0.130374       0
# 4    -2.020505  1.506183       1
# ...        ...       ...     ...
# 1793 -1.789227  0.662834       1
# 1794 -1.334683 -0.353354       1
# 1795 -0.898296 -1.236068       1
# 1796 -1.111784 -0.731093       1
# 1797 -1.281585 -0.415259       1
#
# [1798 rows x 3 columns]

# %%
sns.scatterplot(x= oversample['f1'],y = oversample['f2'],c = oversample['target'])
# Out:
# <AxesSubplot: xlabel='f1', ylabel='f2'>

# %%
sns.scatterplot(x= df['f1'],y=df['f2'],c = df['target'])
# Out:
# <AxesSubplot: xlabel='f1', ylabel='f2'>

# %%
import matplotlib.pyplot as plt
plt.scatter(df['f1'],df['f2'],c = df['target'])

# %%
plt.scatter(oversample['f1'],oversample['f2'],c = oversample['target'])

# %%
df['target'].value_counts()
# Out:
# 0    899
# 1    101
# Name: target, dtype: int64

# %%
oversample['target'].value_counts()
# Out:
# 0    899
# 1    899
# Name: target, dtype: int64
